# %% [markdown]
# Phân loại Bắc hay Nam với sklearn sử dụng Multinomial

# %%
from __future__ import print_function
from sklearn.naive_bayes import MultinomialNB
import numpy as np

# %%
# train data
d1 = [2, 1, 1, 0, 0, 0, 0, 0, 0]
d2 = [1, 1, 0, 1, 1, 0, 0, 0, 0]
d3 = [0, 1, 0, 0, 1, 1, 0, 0, 0]
d4 = [0, 1, 0, 0, 0, 0, 1, 1, 1]

train_data = np.array([d1,d2,d3,d4])
label = np.array(['B','B','B','N'])

# %%
#test data
d5 = np.array([[2, 0, 0, 1, 0, 0, 0, 1, 0]])
d6 = np.array([[0, 1, 0, 0, 0, 0, 0, 1, 1]])

# %%
# tao model
model = MultinomialNB()
# train
model.fit(train_data,label)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
# du doan
print('Prediction of d5: ',str(model.predict(d5)[0]))
print('Probality of d6 in each class: ', model.predict_proba(d6))
# Out:
# Prediction of d5:  B
# Probality of d6 in each class:  [[0.29175335 0.70824665]]

# %% [markdown]
# Phân loại Bắc hay Nam với sklearn sử dụng Bernoulli

# %%
from sklearn.naive_bayes import BernoulliNB

# %%
model2 = BernoulliNB()
model2.fit(train_data,label)
# Out:
# BernoulliNB(alpha=1.0, binarize=0.0, class_prior=None, fit_prior=True)

# %%
# du doan
print('Prediction of d5: ',str(model.predict(d5)[0]))
print('Probality of d6 in each class: ', model.predict_proba(d6))
# Out:
# Prediction of d5:  B
# Probality of d6 in each class:  [[0.16948581 0.83051419]]
